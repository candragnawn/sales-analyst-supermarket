# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("https://raw.githubusercontent.com/sushantag9/Supermarket-Sales-Data-Analysis/master/supermarket_sales%20-%20Sheet1.csv")
df.head(100)
# Out:
#      Invoice ID Branch       City Customer type  Gender  \
# 0   750-67-8428      A     Yangon        Member  Female
# 1   226-31-3081      C  Naypyitaw        Normal  Female
# 2   631-41-3108      A     Yangon        Normal    Male
# 3   123-19-1176      A     Yangon        Member    Male
# 4   373-73-7910      A     Yangon        Normal    Male
# ..          ...    ...        ...           ...     ...
# 95  594-34-4444      A     Yangon        Normal    Male
# 96  766-85-7061      B   Mandalay        Normal    Male
# 97  871-39-9221      C  Naypyitaw        Normal  Female
# 98  865-92-6136      A     Yangon        Normal    Male
# 99  733-01-9107      B   Mandalay        Normal    Male
#
#               Product line  Unit price  Quantity   Tax 5%     Total  \
# 0        Health and beauty       74.69         7  26.1415  548.9715
# 1   Electronic accessories       15.28         5   3.8200   80.2200
# 2       Home and lifestyle       46.33         7  16.2155  340.5255
# 3        Health and beauty       58.22         8  23.2880  489.0480
# 4        Sports and travel       86.31         7  30.2085  634.3785
# ..                     ...         ...       ...      ...       ...
# 95  Electronic accessories       97.16         1   4.8580  102.0180
# 96       Health and beauty       87.87        10  43.9350  922.6350
# 97  Electronic accessories       12.45         6   3.7350   78.4350
# 98      Food and beverages       52.75         3   7.9125  166.1625
# 99      Home and lifestyle       82.70         6  24.8100  521.0100
#
#          Date   Time      Payment    cogs  gross margin percentage  \
# 0    1/5/2019  13:08      Ewallet  522.83                 4.761905
# 1    3/8/2019  10:29         Cash   76.40                 4.761905
# 2    3/3/2019  13:23  Credit card  324.31                 4.761905
# 3   1/27/2019  20:33      Ewallet  465.76                 4.761905
# 4    2/8/2019  10:37      Ewallet  604.17                 4.761905
# ..        ...    ...          ...     ...                      ...
# 95   3/8/2019  20:38      Ewallet   97.16                 4.761905
# 96  3/29/2019  10:25      Ewallet  878.70                 4.761905
# 97   2/9/2019  13:11         Cash   74.70                 4.761905
# 98  3/23/2019  10:16      Ewallet  158.25                 4.761905
# 99   3/5/2019  18:14         Cash  496.20                 4.761905
#
#     gross income  Rating
# 0        26.1415     9.1
# 1         3.8200     9.6
# 2        16.2155     7.4
# 3        23.2880     8.4
# 4        30.2085     5.3
# ..           ...     ...
# 95        4.8580     7.2
# 96       43.9350     5.1
# 97        3.7350     4.1
# 98        7.9125     9.3
# 99       24.8100     7.4
#
# [100 rows x 17 columns]

# %%
df['DateTime'] = pd.to_datetime(df['Date'] + " " + df['Time'])
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# 2        Home and lifestyle       46.33         7  16.2155   340.5255
# 3         Health and beauty       58.22         8  23.2880   489.0480
# 4         Sports and travel       86.31         7  30.2085   634.3785
# ..                      ...         ...       ...      ...        ...
# 995       Health and beauty       40.35         1   2.0175    42.3675
# 996      Home and lifestyle       97.38        10  48.6900  1022.4900
# 997      Food and beverages       31.84         1   1.5920    33.4320
# 998      Home and lifestyle       65.82         1   3.2910    69.1110
# 999     Fashion accessories       88.34         7  30.9190   649.2990
#
#           Date   Time      Payment    cogs  gross margin percentage  \
# 0     1/5/2019  13:08      Ewallet  522.83                 4.761905
# 1     3/8/2019  10:29         Cash   76.40                 4.761905
# 2     3/3/2019  13:23  Credit card  324.31                 4.761905
# 3    1/27/2019  20:33      Ewallet  465.76                 4.761905
# 4     2/8/2019  10:37      Ewallet  604.17                 4.761905
# ..         ...    ...          ...     ...                      ...
# 995  1/29/2019  13:46      Ewallet   40.35                 4.761905
# 996   3/2/2019  17:16      Ewallet  973.80                 4.761905
# 997   2/9/2019  13:22         Cash   31.84                 4.761905
# 998  2/22/2019  15:33         Cash   65.82                 4.761905
# 999  2/18/2019  13:28         Cash  618.38                 4.761905
#
#      gross income  Rating            DateTime
# 0         26.1415     9.1 2019-01-05 13:08:00
# 1          3.8200     9.6 2019-03-08 10:29:00
# 2         16.2155     7.4 2019-03-03 13:23:00
# 3         23.2880     8.4 2019-01-27 20:33:00
# 4         30.2085     5.3 2019-02-08 10:37:00
# ..            ...     ...                 ...
# 995        2.0175     6.2 2019-01-29 13:46:00
# 996       48.6900     4.4 2019-03-02 17:16:00
# 997        1.5920     7.7 2019-02-09 13:22:00
# 998        3.2910     4.1 2019-02-22 15:33:00
# 999       30.9190     6.6 2019-02-18 13:28:00
#
# [1000 rows x 18 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 18 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
#  14  gross margin percentage  1000 non-null   float64
#  15  gross income             1000 non-null   float64
#  16  Rating                   1000 non-null   float64
#  17  DateTime                 1000 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), float64(7), int64(1), object(9)
# memory usage: 140.8+ KB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Payment                  1000 non-null   object
#  11  cogs                     1000 non-null   float64
#  12  gross margin percentage  1000 non-null   float64
#  13  gross income             1000 non-null   float64
#  14  Rating                   1000 non-null   float64
#  15  DateTime                 1000 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), float64(7), int64(1), object(7)
# memory usage: 125.1+ KB

# %%
df.shape
# Out:
# (1000, 17)

# %%
df.tail()
# Out:
#       Invoice ID Branch       City Customer type  Gender         Product line  \
# 995  233-67-5758      C  Naypyitaw        Normal    Male    Health and beauty
# 996  303-96-2227      B   Mandalay        Normal  Female   Home and lifestyle
# 997  727-02-1313      A     Yangon        Member    Male   Food and beverages
# 998  347-56-2442      A     Yangon        Normal    Male   Home and lifestyle
# 999  849-09-3807      A     Yangon        Member  Female  Fashion accessories
#
#      Unit price  Quantity   Tax 5%      Total       Date   Time  Payment  \
# 995       40.35         1   2.0175    42.3675  1/29/2019  13:46  Ewallet
# 996       97.38        10  48.6900  1022.4900   3/2/2019  17:16  Ewallet
# 997       31.84         1   1.5920    33.4320   2/9/2019  13:22     Cash
# 998       65.82         1   3.2910    69.1110  2/22/2019  15:33     Cash
# 999       88.34         7  30.9190   649.2990  2/18/2019  13:28     Cash
#
#        cogs  gross margin percentage  gross income  Rating
# 995   40.35                 4.761905        2.0175     6.2
# 996  973.80                 4.761905       48.6900     4.4
# 997   31.84                 4.761905        1.5920     7.7
# 998   65.82                 4.761905        3.2910     4.1
# 999  618.38                 4.761905       30.9190     6.6

# %%
df.isnull().sum()
# Out:
# Invoice ID                 0
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
#  14  gross margin percentage  1000 non-null   float64
#  15  gross income             1000 non-null   float64
#  16  Rating                   1000 non-null   float64
# dtypes: float64(7), int64(1), object(9)
# memory usage: 132.9+ KB

# %%
df.sort_values('Tax 5%')
# Out:
#       Invoice ID Branch       City Customer type  Gender         Product line  \
# 822  784-21-9238      C  Naypyitaw        Member    Male    Sports and travel
# 629  308-39-1707      A     Yangon        Normal  Female  Fashion accessories
# 223  279-62-1445      C  Naypyitaw        Member  Female  Fashion accessories
# 443  192-98-7397      C  Naypyitaw        Normal    Male  Fashion accessories
# 402  236-86-3015      C  Naypyitaw        Member    Male   Home and lifestyle
# ..           ...    ...        ...           ...     ...                  ...
# 996  303-96-2227      B   Mandalay        Normal  Female   Home and lifestyle
# 699  751-41-9720      C  Naypyitaw        Normal    Male   Home and lifestyle
# 557  283-26-5248      C  Naypyitaw        Member  Female   Food and beverages
# 167  687-47-8271      A     Yangon        Normal    Male  Fashion accessories
# 350  860-79-0874      C  Naypyitaw        Member  Female  Fashion accessories
#
#      Unit price  Quantity   Tax 5%      Total       Date   Time      Payment  \
# 822       10.17         1   0.5085    10.6785   2/7/2019  14:15         Cash
# 629       12.09         1   0.6045    12.6945  1/26/2019  18:19  Credit card
# 223       12.54         1   0.6270    13.1670  2/21/2019  12:38         Cash
# 443       12.78         1   0.6390    13.4190   1/8/2019  14:11      Ewallet
# 402       13.98         1   0.6990    14.6790   2/4/2019  13:38      Ewallet
# ..          ...       ...      ...        ...        ...    ...          ...
# 996       97.38        10  48.6900  1022.4900   3/2/2019  17:16      Ewallet
# 699       97.50        10  48.7500  1023.7500  1/12/2019  16:18      Ewallet
# 557       98.52        10  49.2600  1034.4600  1/30/2019  20:23      Ewallet
# 167       98.98        10  49.4900  1039.2900   2/8/2019  16:20  Credit card
# 350       99.30        10  49.6500  1042.6500  2/15/2019  14:53  Credit card
#
#        cogs  gross margin percentage  gross income  Rating
# 822   10.17                 4.761905        0.5085     5.9
# 629   12.09                 4.761905        0.6045     8.2
# 223   12.54                 4.761905        0.6270     8.2
# 443   12.78                 4.761905        0.6390     9.5
# 402   13.98                 4.761905        0.6990     9.8
# ..      ...                      ...           ...     ...
# 996  973.80                 4.761905       48.6900     4.4
# 699  975.00                 4.761905       48.7500     8.0
# 557  985.20                 4.761905       49.2600     4.5
# 167  989.80                 4.761905       49.4900     8.7
# 350  993.00                 4.761905       49.6500     6.6
#
# [1000 rows x 17 columns]

# %%
data = df.query("`Customer type` == 'Member' and Gender == 'Male' and Payment == 'Cash'")
data.value_counts()
# Out:
# Invoice ID   Branch  City       Customer type  Gender  Product line            Unit price  Quantity  Tax 5%   Total     Date       Time   Payment  cogs    gross margin percentage  gross income  Rating
# 102-06-2002  C       Naypyitaw  Member         Male    Sports and travel       25.25       5         6.3125   132.5625  3/20/2019  17:52  Cash     126.25  4.761905                 6.3125        6.1       1
# 106-35-6779  A       Yangon     Member         Male    Home and lifestyle      44.34       2         4.4340   93.1140   3/27/2019  11:26  Cash     88.68   4.761905                 4.4340        5.8       1
# 110-48-7033  B       Mandalay   Member         Male    Fashion accessories     32.62       4         6.5240   137.0040  1/29/2019  14:12  Cash     130.48  4.761905                 6.5240        9.0       1
# 132-23-6451  A       Yangon     Member         Male    Health and beauty       20.97       5         5.2425   110.0925  1/4/2019   13:21  Cash     104.85  4.761905                 5.2425        7.8       1
# 134-75-2619  A       Yangon     Member         Male    Electronic accessories  19.32       7         6.7620   142.0020  3/25/2019  18:51  Cash     135.24  4.761905                 6.7620        6.9       1
#                                                                                                                                                                                                            ..
# 848-24-9445  C       Naypyitaw  Member         Male    Health and beauty       43.70       2         4.3700   91.7700   3/26/2019  18:03  Cash     87.40   4.761905                 4.3700        4.9       1
# 853-23-2453  B       Mandalay   Member         Male    Health and beauty       75.74       4         15.1480  318.1080  2/14/2019  14:35  Cash     302.96  4.761905                 15.1480       7.6       1
# 861-77-0145  C       Naypyitaw  Member         Male    Electronic accessories  81.97       10        40.9850  860.6850  3/3/2019   14:30  Cash     819.70  4.761905                 40.9850       9.2       1
# 877-22-3308  A       Yangon     Member         Male    Health and beauty       15.87       10        7.9350   166.6350  3/13/2019  16:40  Cash     158.70  4.761905                 7.9350        5.8       1
# 885-56-0389  C       Naypyitaw  Member         Male    Fashion accessories     52.35       1         2.6175   54.9675   2/12/2019  17:49  Cash     52.35   4.761905                 2.6175        4.0       1
# Name: count, Length: 78, dtype: int64

# %% [markdown]
# **Line Plot**

# %%
df["Hour"] = df["DateTime"].dt.hour
df["weekday"] = df["DateTime"].dt.weekday
df["month"] = df["DateTime"].dt.month_name()

df_plot = df.groupby("Hour").agg({"Quantity":"sum"}).reset_index()
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# 2        Home and lifestyle       46.33         7  16.2155   340.5255
# 3         Health and beauty       58.22         8  23.2880   489.0480
# 4         Sports and travel       86.31         7  30.2085   634.3785
# ..                      ...         ...       ...      ...        ...
# 995       Health and beauty       40.35         1   2.0175    42.3675
# 996      Home and lifestyle       97.38        10  48.6900  1022.4900
# 997      Food and beverages       31.84         1   1.5920    33.4320
# 998      Home and lifestyle       65.82         1   3.2910    69.1110
# 999     Fashion accessories       88.34         7  30.9190   649.2990
#
#          Payment    cogs  gross margin percentage  gross income  Rating  \
# 0        Ewallet  522.83                 4.761905       26.1415     9.1
# 1           Cash   76.40                 4.761905        3.8200     9.6
# 2    Credit card  324.31                 4.761905       16.2155     7.4
# 3        Ewallet  465.76                 4.761905       23.2880     8.4
# 4        Ewallet  604.17                 4.761905       30.2085     5.3
# ..           ...     ...                      ...           ...     ...
# 995      Ewallet   40.35                 4.761905        2.0175     6.2
# 996      Ewallet  973.80                 4.761905       48.6900     4.4
# 997         Cash   31.84                 4.761905        1.5920     7.7
# 998         Cash   65.82                 4.761905        3.2910     4.1
# 999         Cash  618.38                 4.761905       30.9190     6.6
#
#                DateTime  Hour  weekday     month
# 0   2019-01-05 13:08:00    13        5   January
# 1   2019-03-08 10:29:00    10        4     March
# 2   2019-03-03 13:23:00    13        6     March
# 3   2019-01-27 20:33:00    20        6   January
# 4   2019-02-08 10:37:00    10        4  February
# ..                  ...   ...      ...       ...
# 995 2019-01-29 13:46:00    13        1   January
# 996 2019-03-02 17:16:00    17        5     March
# 997 2019-02-09 13:22:00    13        5  February
# 998 2019-02-22 15:33:00    15        4  February
# 999 2019-02-18 13:28:00    13        0  February
#
# [1000 rows x 19 columns]

# %%
df_plot
# Out:
#     Hour  Quantity
# 0     10       525
# 1     11       513
# 2     12       501
# 3     13       585
# 4     14       495
# 5     15       530
# 6     16       420
# 7     17       415
# 8     18       475
# 9     19       649
# 10    20       402

# %%
sns.lineplot(data=df_plot, x="Hour",y="Quantity")
plt.title("Quantity in Hour")
plt.show()

# %%
df_plot = df.groupby("weekday").agg({"Quantity":"sum"}).reset_index()
df_plot
# Out:
#    weekday  Quantity
# 0        0       638
# 1        1       862
# 2        2       800
# 3        3       755
# 4        4       758
# 5        5       919
# 6        6       778

# %%
sns.lineplot(data=df_plot, x="weekday",y="Quantity")
plt.title("Quantity in week")
plt.show()

# %%
df_plot = df.groupby("month").agg({"Quantity":"sum"}).reset_index()
df_plot
# Out:
#       month  Quantity
# 0  February      1654
# 1   January      1965
# 2     March      1891

# %%
sns.lineplot(data=df_plot, x="month",y="Quantity")
plt.title("Quantity in month")
plt.show()

# %%
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total  \
# 0       Health and beauty       74.69         7  26.1415  548.9715
# 1  Electronic accessories       15.28         5   3.8200   80.2200
# 2      Home and lifestyle       46.33         7  16.2155  340.5255
# 3       Health and beauty       58.22         8  23.2880  489.0480
# 4       Sports and travel       86.31         7  30.2085  634.3785
#
#        Payment    cogs  gross margin percentage  gross income  Rating  \
# 0      Ewallet  522.83                 4.761905       26.1415     9.1
# 1         Cash   76.40                 4.761905        3.8200     9.6
# 2  Credit card  324.31                 4.761905       16.2155     7.4
# 3      Ewallet  465.76                 4.761905       23.2880     8.4
# 4      Ewallet  604.17                 4.761905       30.2085     5.3
#
#              DateTime  Hour  weekday     month
# 0 2019-01-05 13:08:00    13        5   January
# 1 2019-03-08 10:29:00    10        4     March
# 2 2019-03-03 13:23:00    13        6     March
# 3 2019-01-27 20:33:00    20        6   January
# 4 2019-02-08 10:37:00    10        4  February

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 19 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Payment                  1000 non-null   object
#  11  cogs                     1000 non-null   float64
#  12  gross margin percentage  1000 non-null   float64
#  13  gross income             1000 non-null   float64
#  14  Rating                   1000 non-null   float64
#  15  DateTime                 1000 non-null   datetime64[ns]
#  16  Hour                     1000 non-null   int32
#  17  weekday                  1000 non-null   int32
#  18  month                    1000 non-null   object
# dtypes: datetime64[ns](1), float64(7), int32(2), int64(1), object(8)
# memory usage: 140.8+ KB

# %%
sns.histplot(df, x="Unit price")
# Out:
# <Axes: xlabel='Unit price', ylabel='Count'>

# %%
sns.boxplot(data=df,y="Unit price")
# Out:
# <Axes: ylabel='Unit price'>
